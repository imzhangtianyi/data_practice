# %%
import pandas as pd
import numpy as np
import seaborn as sns
import EDA


filename = "vgsales.csv"
df = pd.read_csv(filename)

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
info = EDA.Info(filename)
info.categories(6)
# Out:
# Rank:
# [1 2 3 4 5]
# int64
# (16598,)
#
# Name:
# ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' 'Wii Sports Resort'
#  'Pokemon Red/Pokemon Blue']
# object
# (11493,)
#
# Platform:
# ['Wii' 'NES' 'GB' 'DS' 'X360']
# object
# (31,)
#
# Year:
# [2006. 1985. 2008. 2009. 1996.]
# float64
# (40,)
#
# Genre:
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle']
# object
# (12,)
#
# Publisher:
# ['Nintendo' 'Microsoft Game Studios' 'Take-Two Interactive'
#  'Sony Computer Entertainment' 'Activision']
# object
# (579,)

# %%
info.missing()
# Out:
# Year:
# 0.016327268345583804
#
# Publisher:
# 0.003494396915290999

# %%
vs = EDA.Visual(df)

# %%
vs.annual_sale(sub=False)

# %%
vs.set_size(14, 20)
vs.avg_sale('Genre')

# %%
vs.set_size(14, 10)
vs.sale_rank('Genre', avg=False)

# %%
vs.set_size(14, 20)
vs.avg_sale('Platform')

# %%
vs.set_size(14, 10)
sns.set_palette('Set2')
vs.sale_rank('Platform', avg=False)

# %%
vs.set_size(14, 20)
vs.avg_sale('Publisher')

# %%
vs.hist('Global_Sales', log=True)
# Out:
# /home/tianyi/anaconda3/envs/insight/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
vs.hist('JP_Sales', log=True)
print(df.JP_Sales.describe())
print(sum(df.JP_Sales == 0)/df.shape[0])
# Out:
# /home/tianyi/anaconda3/envs/insight/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# count    16598.000000
# mean         0.077782
# std          0.309291
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.040000
# max         10.220000
# Name: JP_Sales, dtype: float64
# 0.6298951680925413

# %%
vs.hist('NA_Sales', log=True)
print(df.NA_Sales.describe())
print(sum(df.NA_Sales == 0)/df.shape[0])
# Out:
# /home/tianyi/anaconda3/envs/insight/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# count    16598.000000
# mean         0.264667
# std          0.816683
# min          0.000000
# 25%          0.000000
# 50%          0.080000
# 75%          0.240000
# max         41.490000
# Name: NA_Sales, dtype: float64
# 0.27105675382576216

# %%
vs.hist('EU_Sales', log=True)
print(df.EU_Sales.describe())
print(sum(df.EU_Sales == 0)/df.shape[0])
# Out:
# /home/tianyi/anaconda3/envs/insight/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# count    16598.000000
# mean         0.146652
# std          0.505351
# min          0.000000
# 25%          0.000000
# 50%          0.020000
# 75%          0.110000
# max         29.020000
# Name: EU_Sales, dtype: float64
# 0.34522231594167974

# %%
df.Publisher.shape
# Out:
# (16598,)

# %%
df.dropna(subset=['Publisher']).shape
# Out:
# (16540, 11)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
X = [['Male', 1], ['Female', 3], ['Female', 2]]
enc.fit(X)
# Out:
# /home/tianyi/anaconda3/envs/insight/lib/python3.7/site-packages/sklearn/utils/__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-6e8100253502> in <module>()
#       2 enc = OneHotEncoder(handle_unknown='ignore')
#       3 X = [['Male', 1], ['Female', 3], ['Female', 2]]
# ----> 4 enc.fit(X)
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#    1954         self
#    1955         """
# -> 1956         self.fit_transform(X)
#    1957         return self
#    1958
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/sklearn/preprocessing/data.py in fit_transform(self, X, y)
#    2017         """
# ...
